# %%
# csv 파일 로드
import csv
file=open('210416.csv',encoding='cp949') # 변수명=open(파일 경로,encoding 작업)
data = csv.reader(file)
header=next(data)
#-----------------------------------

Data_list=[]    
for i in data:
    Data_list.append(i[6])
    
file.close()

class List_Num_Count:
#     def __init__(self):
#         pass
    
    def Counts(self,list_input,name_input_list):
        count=0
        for i in list_input:
            for name_input in name_input_list:
                if name_input in i[:3]:
                    count+=1
        return count
    
City=List_Num_Count()
######################################## 리스트 화 시켜서 좀 더 줄이자
Seoul=City.Counts(Data_list,['서울'])
Daejeon=City.Counts(Data_list,['대전'])
Daegu=City.Counts(Data_list,['대구'])
Busan=City.Counts(Data_list,['부산'])
Gwangju=City.Counts(Data_list,['광주'])
Incheon=City.Counts(Data_list,['인천'])
Ulsan=City.Counts(Data_list,['울산'])
Jeju=City.Counts(Data_list,['제주'])
Sejong=City.Counts(Data_list,['세종'])

Gangwon=City.Counts(Data_list,['강원'])
Gyeonggi=City.Counts(Data_list,['경기'])
Gyeongsang=City.Counts(Data_list,['경상','경남','경북'])
Jeolla=City.Counts(Data_list,['전라','전남','전북','전주'])
Chungcheong=City.Counts(Data_list,['충청','충남','충북'])
###################################################################################
# pie 그래프 폰트 설정
font_name = font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)
style.use('ggplot')

#pie 그래프 모형 

colors = ['gold', 'hotpink', 'yellow', 'lightskyblue', 'yellowgreen',\
         'orange', 'red']
labels = ['서울', '대전', '대구', '부산', '광주','인천','울산']
ratio = [Seoul, Daejeon, Daegu, Busan, Gwangju,Incheon, Ulsan]
explode = (0.0, 0.0, 0.2, 0.0, 0.0, 0.0, 0.0)

plt.pie(ratio)

plt.pie(ratio, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=90)
plt.legend(labels,loc='upper right',bbox_to_anchor=(1.3,0.5))


plt.show()
